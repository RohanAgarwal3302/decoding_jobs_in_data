# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Lets first load up the libraries we need to perform our cleaning.
#
# (for this run the code chunk given below)

# %%
import pandas as pd
import re
# Out:
# C:\Users\rohan\AppData\Local\Temp\ipykernel_6264\581249992.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# Now lets load up the our dataset. In order to keep it simple, I will just name the dataset as "data".

# %%
data = pd.read_csv(r"uncleaned_ds.csv")

# %% [markdown]
# Lets have a look into our data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              672 non-null    int64
#  1   Job Title          672 non-null    object
#  2   Salary Estimate    672 non-null    object
#  3   Job Description    672 non-null    object
#  4   Rating             672 non-null    float64
#  5   Company Name       672 non-null    object
#  6   Location           672 non-null    object
#  7   Headquarters       672 non-null    object
#  8   Size               672 non-null    object
#  9   Founded            672 non-null    int64
#  10  Type of ownership  672 non-null    object
#  11  Industry           672 non-null    object
#  12  Sector             672 non-null    object
#  13  Revenue            672 non-null    object
#  14  Competitors        672 non-null    object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 78.9+ KB

# %%
data.head(10)
# Out:
#    index                                 Job Title  \
# 0      0                         Sr Data Scientist
# 1      1                            Data Scientist
# 2      2                            Data Scientist
# 3      3                            Data Scientist
# 4      4                            Data Scientist
# 5      5                            Data Scientist
# 6      6  Data Scientist / Machine Learning Expert
# 7      7                            Data Scientist
# 8      8          Staff Data Scientist - Analytics
# 9      9                            Data Scientist
#
#                 Salary Estimate  \
# 0  $137K-$171K (Glassdoor est.)
# 1  $137K-$171K (Glassdoor est.)
# 2  $137K-$171K (Glassdoor est.)
# 3  $137K-$171K (Glassdoor est.)
# 4  $137K-$171K (Glassdoor est.)
# 5  $137K-$171K (Glassdoor est.)
# 6  $137K-$171K (Glassdoor est.)
# 7  $137K-$171K (Glassdoor est.)
# 8  $137K-$171K (Glassdoor est.)
# 9  $137K-$171K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Description\n\nThe Senior Data Scientist is re...     3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...     4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...     3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...     3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
# 5  About Us:\n\nHeadquartered in beautiful Santa ...     4.2
# 6  Posting Title\nData Scientist / Machine Learni...     3.9
# 7  Introduction\n\nHave you always wanted to run ...     3.5
# 8  Intuit is seeking a Staff Data Scientist to co...     4.4
# 9  Ready to write the best chapter of your career...     3.6
#
#               Company Name           Location            Headquarters  \
# 0         Healthfirst\n3.1       New York, NY            New York, NY
# 1             ManTech\n4.2      Chantilly, VA             Herndon, VA
# 2      Analysis Group\n3.8         Boston, MA              Boston, MA
# 3             INFICON\n3.5         Newton, MA  Bad Ragaz, Switzerland
# 4  Affinity Solutions\n2.9       New York, NY            New York, NY
# 5         HG Insights\n4.2  Santa Barbara, CA       Santa Barbara, CA
# 6            Novartis\n3.9      Cambridge, MA      Basel, Switzerland
# 7              iRobot\n3.5        Bedford, MA             Bedford, MA
# 8       Intuit - Data\n4.4      San Diego, CA       Mountain View, CA
# 9  XSELL Technologies\n3.6        Chicago, IL             Chicago, IL
#
#                       Size  Founded        Type of ownership  \
# 0   1001 to 5000 employees     1993   Nonprofit Organization
# 1  5001 to 10000 employees     1968         Company - Public
# 2   1001 to 5000 employees     1981  Private Practice / Firm
# 3    501 to 1000 employees     2000         Company - Public
# 4      51 to 200 employees     1998        Company - Private
# 5      51 to 200 employees     2010        Company - Private
# 6         10000+ employees     1996         Company - Public
# 7   1001 to 5000 employees     1990         Company - Public
# 8  5001 to 10000 employees     1983         Company - Public
# 9      51 to 200 employees     2014        Company - Private
#
#                                    Industry                     Sector  \
# 0                        Insurance Carriers                  Insurance
# 1                    Research & Development          Business Services
# 2                                Consulting          Business Services
# 3     Electrical & Electronic Manufacturing              Manufacturing
# 4                   Advertising & Marketing          Business Services
# 5              Computer Hardware & Software     Information Technology
# 6                 Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
# 7  Consumer Electronics & Appliances Stores                     Retail
# 8              Computer Hardware & Software     Information Technology
# 9   Enterprise Software & Network Solutions     Information Technology
#
#                       Revenue  \
# 0    Unknown / Non-Applicable
# 1      $1 to $2 billion (USD)
# 2  $100 to $500 million (USD)
# 3  $100 to $500 million (USD)
# 4    Unknown / Non-Applicable
# 5    Unknown / Non-Applicable
# 6          $10+ billion (USD)
# 7      $1 to $2 billion (USD)
# 8      $2 to $5 billion (USD)
# 9    Unknown / Non-Applicable
#
#                                          Competitors
# 0            EmblemHealth, UnitedHealth Group, Aetna
# 1                                                 -1
# 2                                                 -1
# 3  MKS Instruments, Pfeiffer Vacuum, Agilent Tech...
# 4               Commerce Signals, Cardlytics, Yodlee
# 5                                                 -1
# 6                                                 -1
# 7                                                 -1
# 8                          Square, PayPal, H&R Block
# 9                                                 -1

# %% [markdown]
# Looks like we donot have any null values in the data and the empty field are formatted as "-1". Since, the variables which contain "-1" are not quantitative variables, therefore we cannot do much about it.

# %% [markdown]
# Let's remove the columns we wont be requiring for our analysis.

# %%
data.drop(columns={"index","Rating","Headquarters","Size","Founded","Revenue","Competitors"},inplace=True)
data.head()
# Out:
#            Job Title               Salary Estimate  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description             Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...         Healthfirst\n3.1
# 1  Secure our Nation, Ignite your Future\n\nJoin ...             ManTech\n4.2
# 2  Overview\n\n\nAnalysis Group is one of the lar...      Analysis Group\n3.8
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...             INFICON\n3.5
# 4  Data Scientist\nAffinity Solutions / Marketing...  Affinity Solutions\n2.9
#
#         Location        Type of ownership  \
# 0   New York, NY   Nonprofit Organization
# 1  Chantilly, VA         Company - Public
# 2     Boston, MA  Private Practice / Firm
# 3     Newton, MA         Company - Public
# 4   New York, NY        Company - Private
#
#                                 Industry             Sector
# 0                     Insurance Carriers          Insurance
# 1                 Research & Development  Business Services
# 2                             Consulting  Business Services
# 3  Electrical & Electronic Manufacturing      Manufacturing
# 4                Advertising & Marketing  Business Services

# %% [markdown]
# That did the job. Now lets check for duplicates.

# %%
data.duplicated().sum()
# Out:
# 13

# %% [markdown]
# That's a small number. Lets delete them now.

# %%
data.drop_duplicates(inplace=True)

# %% [markdown]
# We need to check wether those rows with "-1" need to be removed or not.

# %%
data[(data["Industry"]=="-1")]
# Out:
#                                              Job Title  \
# 42                                      Data Analyst I
# 154                   ELISA RESEARCH SCIENTIST (CV-15)
# 158                          Machine Learning Engineer
# 168                                      Data Engineer
# 193                                     Data Scientist
# 195                                     Data Scientist
# 248                                     Data Scientist
# 251                                     Data Scientist
# 258                                     Data Scientist
# 272                                     Data Scientist
# 274                                     Data Scientist
# 282                                     Data Scientist
# 285                                     Data Scientist
# 288                                     Data Scientist
# 290                                     Data Scientist
# 308                                     Data Scientist
# 316                                     Data Scientist
# 322                                     Data Scientist
# 335                                     Data Scientist
# 338                                     Data Scientist
# 348                                     Data Scientist
# 351                                     Data Scientist
# 357                                     Data Scientist
# 371                                     Data Scientist
# 388                                     Data Scientist
# 409                                     Data Scientist
# 424                                     Data Scientist
# 430                                     Data Scientist
# 431                                     Data Scientist
# 435                                     Data Scientist
# 438                                     Data Scientist
# 441                                     Data Scientist
# 457                                     Data Scientist
# 459                                     Data Scientist
# 476                                     Data Scientist
# 478                                     Data Scientist
# 494                                     Data Scientist
# 495                                     Data Scientist
# 504                                     Data Scientist
# 515                                     Data Scientist
# 519             Scientist / Group Lead, Cancer Biology
# 524                                     Data Scientist
# 531                                     Data Scientist
# 555                                     Data Scientist
# 568                                     Data Scientist
# 585  Sr. Research Associate/ Scientist, NGS prep & ...
# 598                                     Data Scientist
# 610                                     Data Scientist
# 613                                     Data Scientist
# 615                                     Data Scientist
# 621                                     Data Scientist
# 637                                     Data Scientist
# 650             Scientist / Group Lead, Cancer Biology
# 656                                     Data Scientist
# 657                                     Data Scientist
# 660                                     Data Scientist
# 662                                     Data Scientist
# 664                                     Data Scientist
# 668                                     Data Scientist
# 669                                     Data Scientist
#
#                   Salary Estimate  \
# 42    $75K-$131K (Glassdoor est.)
# 154   $90K-$109K (Glassdoor est.)
# 158  $101K-$165K (Glassdoor est.)
# 168  $101K-$165K (Glassdoor est.)
# 193    $56K-$97K (Glassdoor est.)
# 195    $56K-$97K (Glassdoor est.)
# 248   $90K-$124K (Glassdoor est.)
# 251   $90K-$124K (Glassdoor est.)
# 258   $90K-$124K (Glassdoor est.)
# 272   $91K-$150K (Glassdoor est.)
# 274   $91K-$150K (Glassdoor est.)
# 282   $91K-$150K (Glassdoor est.)
# 285  $141K-$225K (Glassdoor est.)
# 288  $141K-$225K (Glassdoor est.)
# 290  $141K-$225K (Glassdoor est.)
# 308    $145K-$225K(Employer est.)
# 316    $145K-$225K(Employer est.)
# 322    $145K-$225K(Employer est.)
# 335   $79K-$147K (Glassdoor est.)
# 338   $79K-$147K (Glassdoor est.)
# 348  $122K-$146K (Glassdoor est.)
# 351  $122K-$146K (Glassdoor est.)
# 357  $122K-$146K (Glassdoor est.)
# 371  $112K-$116K (Glassdoor est.)
# 388  $110K-$163K (Glassdoor est.)
# 409  $124K-$198K (Glassdoor est.)
# 424  $124K-$198K (Glassdoor est.)
# 430   $79K-$133K (Glassdoor est.)
# 431   $79K-$133K (Glassdoor est.)
# 435   $79K-$133K (Glassdoor est.)
# 438   $79K-$133K (Glassdoor est.)
# 441   $79K-$133K (Glassdoor est.)
# 457   $69K-$116K (Glassdoor est.)
# 459   $69K-$116K (Glassdoor est.)
# 476    $31K-$56K (Glassdoor est.)
# 478    $31K-$56K (Glassdoor est.)
# 494   $95K-$119K (Glassdoor est.)
# 495   $95K-$119K (Glassdoor est.)
# 504   $95K-$119K (Glassdoor est.)
# 515  $212K-$331K (Glassdoor est.)
# 519  $212K-$331K (Glassdoor est.)
# 524  $212K-$331K (Glassdoor est.)
# 531   $66K-$112K (Glassdoor est.)
# 555  $128K-$201K (Glassdoor est.)
# 568  $128K-$201K (Glassdoor est.)
# 585  $138K-$158K (Glassdoor est.)
# 598   $80K-$132K (Glassdoor est.)
# 610   $80K-$132K (Glassdoor est.)
# 613   $87K-$141K (Glassdoor est.)
# 615   $87K-$141K (Glassdoor est.)
# 621   $87K-$141K (Glassdoor est.)
# 637   $92K-$155K (Glassdoor est.)
# 650   $92K-$155K (Glassdoor est.)
# 656  $105K-$167K (Glassdoor est.)
# 657  $105K-$167K (Glassdoor est.)
# 660  $105K-$167K (Glassdoor est.)
# 662  $105K-$167K (Glassdoor est.)
# 664  $105K-$167K (Glassdoor est.)
# 668  $105K-$167K (Glassdoor est.)
# 669  $105K-$167K (Glassdoor est.)
#
#                                        Job Description  \
# 42   Who is Cenlar?\n\nYou are.\n\nEmployee-owners ...
# 154  Covaxx, a subsidiary of the UBI Group, has joi...
# 158  Overview\n\nRadical Convergence is a fast-pace...
# 168  Job Number: 10202\nGroup: Cosma International\...
# 193  Job Description\nClient JD below:\n\nWe need a...
# 195  About Joby\nLocated in Northern California, th...
# 248  Descript is a new kind of audio/video creation...
# 251  We are looking for a Data Scientist to analyze...
# 258  Full Time Data Scientist\n\nThe Drive Media is...
# 272  Business Unit: Data Scientist Comcast brings t...
# 274  Job Description\nClient JD below:\n\nWe need a...
# 282  Greetings from Trovetechs!!!\n\nÂ\n\nWe have a...
# 285  Greetings from Trovetechs!!!\n\nÂ\n\nWe have a...
# 288  About Joby\nLocated in Northern California, th...
# 290  Work Authorization Those authorized to work in...
# 308  Data Scientist\n\nRequirements\nMS or PhD in C...
# 316  Job Description\nEssential Responsibilities:\n...
# 322  Job Description\nData Scientist\nAre you inter...
# 335  One of the largest health insurers in the nati...
# 338  Work in a fast growing startup with unlimited ...
# 348  Title Data Scientist Location Remote (SFMNAZNY...
# 351  About Our AI/ML Team\n\nOur mission is to buil...
# 357  Job Overview: The Data Scientist is a key memb...
# 371  Solution IT Inc. is looking for an Data Scient...
# 388  Job Description\nAs a Data Scientist, you will...
# 409  About Navio:\nNavio builds software tools that...
# 424  Get To Know Voice\n\nAt Voice, we are on a mis...
# 430  Job Description\nFalcon It is seeking a Data S...
# 431  Job Description\nData Scientist\nAre you inter...
# 435  Job Description\nWe are looking for the sharpe...
# 438  Title Data Scientist Location Remote Duration ...
# 441  Job Description\nWe are looking for a Data Sci...
# 457  Work in a fast growing startup with unlimited ...
# 459  We are looking for a highly motivated data sci...
# 476  Job Title : Data Scientist\n\nJob Location : W...
# 478  Responsibilities·\nAnalyze large datasets to g...
# 494  Tygart is currently seeking Data Scientist to ...
# 495  Job Overview: The Data Scientist is a key memb...
# 504  Job Description\nWorking at Sophinea\n\nSophin...
# 515  Ke`aki Technologies is looking for a qualified...
# 519  Scientist / Group Lead, Cancer Biology\nLocati...
# 524  CompuForce is seeking an experienced and highl...
# 531  Job Description\nData Scientist – Washington D...
# 555  Job Description\nAs a Data Scientist, you will...
# 568  At Kibo, we provide cloud commerce solutions i...
# 585  We are seeking a Sr. Research Associate/Scient...
# 598  Job Description:\n\n· Working closely with the...
# 610  Tygart is currently seeking Data Scientist to ...
# 613  DESCRIPTION\n\nGrainBridge is seeking a talent...
# 615  Position Description\n\nSprezzatura seeks a Da...
# 621  Day to Day Responsibilities:\nDaily responsibi...
# 637  Job Description\nWorking at Sophinea\n\nSophin...
# 650  Scientist / Group Lead, Cancer Biology\nLocati...
# 656  Join our team dedicated to developing and exec...
# 657  Overview\n\nGood people, working with good peo...
# 660  Location: Redmond, WA\nClient: Microsoft (Un-M...
# 662  Solution IT Inc. is looking for an Data Scient...
# 664  Job Description\nClear Ridge has an exciting o...
# 668  Job Description\nBecome a thought leader withi...
# 669  Join a thriving company that is changing the w...
#
#                                       Company Name              Location  \
# 42                                     Cenlar\n2.6             Ewing, NJ
# 154                       Covid-19 Search Partners         Hauppauge, NY
# 158                            Radical Convergence            Reston, VA
# 168                  Magna International Inc.\n3.5        Birmingham, AL
# 193                                SkillSoniq\n5.0     San Francisco, CA
# 195                             Joby Aviation\n4.3        San Carlos, CA
# 248                                  Descript\n4.3     San Francisco, CA
# 251                               Better Hire\n4.0        Birmingham, AL
# 258                     The Drive Media, Inc.\n5.0          New York, NY
# 272                                   Comcast\n3.5          New York, NY
# 274                                SkillSoniq\n5.0     San Francisco, CA
# 282                                 Trovetechs Inc     San Francisco, CA
# 285                                 Trovetechs Inc     San Francisco, CA
# 288                             Joby Aviation\n4.3        San Carlos, CA
# 290                                       PETADATA     San Francisco, CA
# 308                            Kollasoft Inc.\n3.2          New York, NY
# 316                 Advance Sourcing Concepts\n3.4        Pittsburgh, PA
# 322                       Rainmaker Resources, LLC        Cincinnati, OH
# 335              Solving IT International Inc\n3.4           Chicago, IL
# 338                                  Stride Search     San Francisco, CA
# 348                            Shimento, Inc.\n2.9       Santa Clara, CA
# 351                               Point72 Ventures         Palo Alto, CA
# 357                                 Hatch Data Inc     San Francisco, CA
# 371                          SolutionIT, Inc.\n4.4            Edison, NJ
# 388                                         HireAi     San Francisco, CA
# 409                                          Navio         San Mateo, CA
# 424                                     Voice\n3.4          Brooklyn, NY
# 430                 Falcon IT & Staffing Solutions      Fort Belvoir, VA
# 431                       Rainmaker Resources, LLC        Cincinnati, OH
# 435                                 PeopleCom\n5.0            McLean, VA
# 438                            Blue Icy Water, LLC         United States
# 441                                    Maxiom\n5.0           Ashburn, VA
# 457                                  Stride Search     San Francisco, CA
# 459                                 Blue Cloak LLC          Sterling, VA
# 476                           Radiant Digital\n4.5        Washington, DC
# 478                     IntelliPro Group Inc.\n4.1       Santa Clara, CA
# 494                    Tygart Technology, Inc\n4.7        Washington, DC
# 495                                 Hatch Data Inc     San Francisco, CA
# 504                                       Sophinea         Chantilly, VA
# 515  Alaka`ina Foundation Family of Companies\n3.6  Fort Sam Houston, TX
# 519                        Monte Rosa Therapeutics         Cambridge, MA
# 524                                     CompuForce          New York, NY
# 531                              JCD Staffing\n5.0        Washington, DC
# 555                                         HireAi     San Francisco, CA
# 568                                           Kibo      Philadelphia, PA
# 585                  Homology Medicines, Inc.\n4.4       New Bedford, MA
# 598                                 Kognetics\n3.6           Gahanna, OH
# 610                    Tygart Technology, Inc\n4.7        Washington, DC
# 613                               GrainBridge, LLC             Omaha, NE
# 615              Sprezzatura Management Consulting        Washington, VA
# 621         Advanced Bio-Logic Solutions Corp\n4.0     Thousand Oaks, CA
# 637                                       Sophinea         Chantilly, VA
# 650                        Monte Rosa Therapeutics         Cambridge, MA
# 656                            Berico Technologies      Fort Belvoir, VA
# 657                         Kehe Food Distributors        Naperville, IL
# 660                                   Pactera Edge           Redmond, WA
# 662                          SolutionIT, Inc.\n4.4            Edison, NJ
# 664                            Clear Ridge Defense          Quantico, VA
# 668                                           JKGT     San Francisco, CA
# 669                                     AccessHope         Irwindale, CA
#
#      Type of ownership Industry Sector
# 42   Company - Private       -1     -1
# 154                 -1       -1     -1
# 158                 -1       -1     -1
# 168   Company - Public       -1     -1
# 193   Company - Public       -1     -1
# 195  Company - Private       -1     -1
# 248  Company - Private       -1     -1
# 251  Company - Private       -1     -1
# 258            Unknown       -1     -1
# 272   Company - Public       -1     -1
# 274   Company - Public       -1     -1
# 282  Company - Private       -1     -1
# 285  Company - Private       -1     -1
# 288  Company - Private       -1     -1
# 290  Company - Private       -1     -1
# 308   Company - Public       -1     -1
# 316  Company - Private       -1     -1
# 322  Company - Private       -1     -1
# 335  Company - Private       -1     -1
# 338  Company - Private       -1     -1
# 348  Company - Private       -1     -1
# 351                 -1       -1     -1
# 357                 -1       -1     -1
# 371  Company - Private       -1     -1
# 388                 -1       -1     -1
# 409            Unknown       -1     -1
# 424  Company - Private       -1     -1
# 430   Company - Public       -1     -1
# 431  Company - Private       -1     -1
# 435  Company - Private       -1     -1
# 438  Company - Private       -1     -1
# 441   Company - Public       -1     -1
# 457  Company - Private       -1     -1
# 459                 -1       -1     -1
# 476  Company - Private       -1     -1
# 478  Company - Private       -1     -1
# 494  Company - Private       -1     -1
# 495                 -1       -1     -1
# 504            Unknown       -1     -1
# 515         Government       -1     -1
# 519                 -1       -1     -1
# 524  Company - Private       -1     -1
# 531  Company - Private       -1     -1
# 555                 -1       -1     -1
# 568   Company - Public       -1     -1
# 585   Company - Public       -1     -1
# 598  Company - Private       -1     -1
# 610  Company - Private       -1     -1
# 613                 -1       -1     -1
# 615  Company - Private       -1     -1
# 621  Company - Private       -1     -1
# 637            Unknown       -1     -1
# 650                 -1       -1     -1
# 656                 -1       -1     -1
# 657                 -1       -1     -1
# 660                 -1       -1     -1
# 662  Company - Private       -1     -1
# 664  Company - Private       -1     -1
# 668                 -1       -1     -1
# 669                 -1       -1     -1

# %% [markdown]
# Looks like "-1" only appears in the last three columns of the dataset and dropping such rows will lead to a loss in relevant information. So, we will leave them as they are.

# %% [markdown]
# Now lets start formatting the columns. The number given after the names of the company are the ratings of the company, we donot require them , so we will strip them out.

# %%
data["Company Name"]=data["Company Name"].str.split("\n").str[0]

data.head()
# Out:
#            Job Title               Salary Estimate  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description        Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...         Healthfirst
# 1  Secure our Nation, Ignite your Future\n\nJoin ...             ManTech
# 2  Overview\n\n\nAnalysis Group is one of the lar...      Analysis Group
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...             INFICON
# 4  Data Scientist\nAffinity Solutions / Marketing...  Affinity Solutions
#
#         Location        Type of ownership  \
# 0   New York, NY   Nonprofit Organization
# 1  Chantilly, VA         Company - Public
# 2     Boston, MA  Private Practice / Firm
# 3     Newton, MA         Company - Public
# 4   New York, NY        Company - Private
#
#                                 Industry             Sector
# 0                     Insurance Carriers          Insurance
# 1                 Research & Development  Business Services
# 2                             Consulting  Business Services
# 3  Electrical & Electronic Manufacturing      Manufacturing
# 4                Advertising & Marketing  Business Services

# %% [markdown]
# Good. In a similar way we will remove the state code from "Location" column.

# %%
data["Location"]=data["Location"].str.split(',').str[0]

data.head()
# Out:
#            Job Title               Salary Estimate  \
# 0  Sr Data Scientist  $137K-$171K (Glassdoor est.)
# 1     Data Scientist  $137K-$171K (Glassdoor est.)
# 2     Data Scientist  $137K-$171K (Glassdoor est.)
# 3     Data Scientist  $137K-$171K (Glassdoor est.)
# 4     Data Scientist  $137K-$171K (Glassdoor est.)
#
#                                      Job Description        Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...         Healthfirst
# 1  Secure our Nation, Ignite your Future\n\nJoin ...             ManTech
# 2  Overview\n\n\nAnalysis Group is one of the lar...      Analysis Group
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...             INFICON
# 4  Data Scientist\nAffinity Solutions / Marketing...  Affinity Solutions
#
#     Location        Type of ownership                               Industry  \
# 0   New York   Nonprofit Organization                     Insurance Carriers
# 1  Chantilly         Company - Public                 Research & Development
# 2     Boston  Private Practice / Firm                             Consulting
# 3     Newton         Company - Public  Electrical & Electronic Manufacturing
# 4   New York        Company - Private                Advertising & Marketing
#
#               Sector
# 0          Insurance
# 1  Business Services
# 2  Business Services
# 3      Manufacturing
# 4  Business Services

# %% [markdown]
# We will be now spliting the "Salary Estimate" column into minimum and maximum estimated salary. For this, we will first remove the strings inside the brackets and then split the column and format the newly created collumns as int.

# %%
data["Salary Estimate"] = data['Salary Estimate'].str.replace('(Glassdoor est.)', '').str.replace('(Employer est.)', '')

# %%
data[["Min Salary($)","Max Salary($)"]]=data["Salary Estimate"].str.split("-",expand=True)

# %%
data["Min Salary($)"]=data["Min Salary($)"].str.replace('$',"").str.replace("K","000").astype(int)
data["Max Salary($)"]=data["Max Salary($)"].str.replace('$',"").str.replace("K","000").astype(int)

data.head()
# Out:
#            Job Title Salary Estimate  \
# 0  Sr Data Scientist    $137K-$171K
# 1     Data Scientist    $137K-$171K
# 2     Data Scientist    $137K-$171K
# 3     Data Scientist    $137K-$171K
# 4     Data Scientist    $137K-$171K
#
#                                      Job Description        Company Name  \
# 0  Description\n\nThe Senior Data Scientist is re...         Healthfirst
# 1  Secure our Nation, Ignite your Future\n\nJoin ...             ManTech
# 2  Overview\n\n\nAnalysis Group is one of the lar...      Analysis Group
# 3  JOB DESCRIPTION:\n\nDo you have a passion for ...             INFICON
# 4  Data Scientist\nAffinity Solutions / Marketing...  Affinity Solutions
#
#     Location        Type of ownership                               Industry  \
# 0   New York   Nonprofit Organization                     Insurance Carriers
# 1  Chantilly         Company - Public                 Research & Development
# 2     Boston  Private Practice / Firm                             Consulting
# 3     Newton         Company - Public  Electrical & Electronic Manufacturing
# 4   New York        Company - Private                Advertising & Marketing
#
#               Sector  Min Salary($)  Max Salary($)
# 0          Insurance         137000         171000
# 1  Business Services         137000         171000
# 2  Business Services         137000         171000
# 3      Manufacturing         137000         171000
# 4  Business Services         137000         171000

# %% [markdown]
# We dont require the "Salary Estimate" column anymore, so, lets drop it.

# %%
data.drop(columns="Salary Estimate", inplace=True)

# %% [markdown]
# Lets create another column as "Average Salary" using "Min salary" and "Max Salary"

# %%
data["Average Salary"]=(data["Min Salary($)"]+data["Max Salary($)"])//2

# %% [markdown]
# We will now find out the minimum qualification mentioned in the "Job Description" and create a column "Min Qualification".
#
# For this I have created a functions that uses regular expressions to search for keywords:- bachelors, b.s, masters, m.s, and phd.

# %%
def qualification(job_description:str):
    if re.search(r'\Bachelo\w+',job_description.lower()):
        return re.search(r'.\Bachelo\w+',job_description.lower()).group()
    elif re.search(r'\bb\.?s\b', job_description.lower()):
        return re.search(r'\bb\.?s\b', job_description.lower()).group()
    elif re.search(r'\bmaster\S?s',job_description.lower()):
        return re.search(r'\bmaster\S?s',job_description.lower()).group()
    elif re.search(r'\bm\.?s\b', job_description.lower()):
        return re.search(r'\bm\.?s\b', job_description.lower()).group()
    elif re.search(r'\bph\.?d\b',job_description.lower()):
        return "Phd"
    elif re.search(r'\badvanced\s+degree\b', job_description.lower()):
        return re.search(r'\badvanced\s+degree\b', job_description.lower()).group()
    
data["Min Qualification"]=data["Job Description"].apply(qualification)

data.head()
# Out:
#            Job Title                                    Job Description  \
# 0  Sr Data Scientist  Description\n\nThe Senior Data Scientist is re...
# 1     Data Scientist  Secure our Nation, Ignite your Future\n\nJoin ...
# 2     Data Scientist  Overview\n\n\nAnalysis Group is one of the lar...
# 3     Data Scientist  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4     Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
#
#          Company Name   Location        Type of ownership  \
# 0         Healthfirst   New York   Nonprofit Organization
# 1             ManTech  Chantilly         Company - Public
# 2      Analysis Group     Boston  Private Practice / Firm
# 3             INFICON     Newton         Company - Public
# 4  Affinity Solutions   New York        Company - Private
#
#                                 Industry             Sector  Min Salary($)  \
# 0                     Insurance Carriers          Insurance         137000
# 1                 Research & Development  Business Services         137000
# 2                             Consulting  Business Services         137000
# 3  Electrical & Electronic Manufacturing      Manufacturing         137000
# 4                Advertising & Marketing  Business Services         137000
#
#    Max Salary($)  Average Salary Min Qualification
# 0         171000          154000          bachelor
# 1         171000          154000          bachelor
# 2         171000          154000               Phd
# 3         171000          154000          bachelor
# 4         171000          154000   advanced degree

# %% [markdown]
# Now lets check the different values in our newly created column.

# %%
data["Min Qualification"].value_counts()
# Out:
# Min Qualification
# bachelor           202
# bs                  66
# bachelors           50
# ms                  44
# Phd                 39
# masters             23
# master’s            23
# master's            16
# b.s                 16
# m.s                 11
# advanced degree     10
# bachelorrsquos       4
# masterrs             1
# bachelorâs           1
# Name: count, dtype: int64

# %% [markdown]
# Although this looks like there are too many different qualifications but we can broadly clasify them as : Bachelors, Masters, and Phd

# %%
def cleaning(text):
    if re.search(r'\bb',text):
        return "Bachelors"
    elif re.search(r'\bP',text):
        return "Phd"
    else:
        return "Masters"
    
data['Min Qualification']=data[(data['Min Qualification'].isnull()!=True)]["Min Qualification"].apply(cleaning)

# %% [markdown]
# Now lets find out which programming languages are reqiured for the job. We will do this by creating boolean columns for Python, SQL, R, C,C++ and C#.

# %%
def py(txt):
    if re.search(r'\Bython\b',txt.lower()):
        return True

def R(txt):
    if re.search(r'\br\b',txt.lower()):
        return True

def SQL(txt):
    if re.search(r'\bsql\b',txt.lower()):
        return True
    
def Others(txt):
    if re.search(r'\bc[,+#]?\b',txt.lower()):
        return True

data["Python"]=data['Job Description'].apply(py)
data["R"]=data['Job Description'].apply(R)
data["SQL"]=data['Job Description'].apply(SQL)
data["C/C++/C#"]=data['Job Description'].apply(Others)

data.head()
# Out:
#            Job Title                                    Job Description  \
# 0  Sr Data Scientist  Description\n\nThe Senior Data Scientist is re...
# 1     Data Scientist  Secure our Nation, Ignite your Future\n\nJoin ...
# 2     Data Scientist  Overview\n\n\nAnalysis Group is one of the lar...
# 3     Data Scientist  JOB DESCRIPTION:\n\nDo you have a passion for ...
# 4     Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
#
#          Company Name   Location        Type of ownership  \
# 0         Healthfirst   New York   Nonprofit Organization
# 1             ManTech  Chantilly         Company - Public
# 2      Analysis Group     Boston  Private Practice / Firm
# 3             INFICON     Newton         Company - Public
# 4  Affinity Solutions   New York        Company - Private
#
#                                 Industry             Sector  Min Salary($)  \
# 0                     Insurance Carriers          Insurance         137000
# 1                 Research & Development  Business Services         137000
# 2                             Consulting  Business Services         137000
# 3  Electrical & Electronic Manufacturing      Manufacturing         137000
# 4                Advertising & Marketing  Business Services         137000
#
#    Max Salary($)  Average Salary Min Qualification Python     R   SQL C/C++/C#
# 0         171000          154000         Bachelors   None  None  None     None
# 1         171000          154000         Bachelors   None  None  True     None
# 2         171000          154000               Phd   True  True  None     True
# 3         171000          154000         Bachelors   True  None  True     None
# 4         171000          154000           Masters   True  True  True     None

# %% [markdown]
# And now, since we have extracted everything we need for our analysis, we will drop the "Job description" which we dont require anymore.

# %%
data.drop(columns="Job Description",inplace=True)

# %% [markdown]
# Finally we are done with our cleaning. Lets, for the last time, view our dataset to check everything is in order.

# %%
data.head()
# Out:
#            Job Title        Company Name   Location        Type of ownership  \
# 0  Sr Data Scientist         Healthfirst   New York   Nonprofit Organization
# 1     Data Scientist             ManTech  Chantilly         Company - Public
# 2     Data Scientist      Analysis Group     Boston  Private Practice / Firm
# 3     Data Scientist             INFICON     Newton         Company - Public
# 4     Data Scientist  Affinity Solutions   New York        Company - Private
#
#                                 Industry             Sector  Min Salary($)  \
# 0                     Insurance Carriers          Insurance         137000
# 1                 Research & Development  Business Services         137000
# 2                             Consulting  Business Services         137000
# 3  Electrical & Electronic Manufacturing      Manufacturing         137000
# 4                Advertising & Marketing  Business Services         137000
#
#    Max Salary($)  Average Salary Min Qualification Python     R   SQL C/C++/C#
# 0         171000          154000         Bachelors   None  None  None     None
# 1         171000          154000         Bachelors   None  None  True     None
# 2         171000          154000               Phd   True  True  None     True
# 3         171000          154000         Bachelors   True  None  True     None
# 4         171000          154000           Masters   True  True  True     None

# %% [markdown]
# Looks good.
